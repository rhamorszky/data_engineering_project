# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
import json
import os

import pandas as pd
import requests

# %%
url = "https://data.cityofchicago.org/resource/ajtu-isnz.json?trip_id=000001dd3888f74eaf131b0627d367e8c5b73cc4"

response = requests.get(url)

data = response.json()

data
# Out:
# [{'trip_id': '000001dd3888f74eaf131b0627d367e8c5b73cc4',
#   'taxi_id': 'd5fc0adc436b269c2ce07e37eff1af604a963c8538536bd6be39f0b399c0a6b14bafdaca01d34d939738ae4df46ddbeaf7b83aeb4506199bb645112e791e07e9',
#   'trip_start_timestamp': '2024-02-26T14:30:00.000',
#   'trip_end_timestamp': '2024-02-26T15:15:00.000',
#   'trip_seconds': '2640',
#   'trip_miles': '16.3',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '5',
#   'fare': '42.75',
#   'tips': '12.05',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '59.8',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.947791586',
#   'dropoff_centroid_longitude': '-87.683834942',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6838349425, 41.9477915865]}}]

# %%
# current_datetime = datetime.now() - relativedelta(months=2)
# formatted_datetime = current_datetime.strftime("%Y-%m-%d")

# url = (
#     "https://data.cityofchicago.org/resource/ajtu-isnz.json?"
#     f"$where=trip_start_timestamp >= {formatted_datetime}T00:00:00"
#     f" AND trip_start_timestamp <= {formatted_datetime}T23:59:59&$limit=30000"
# )

# response = requests.get(url)

# data = response.json()

# data
# Out:
# {'code': 'query.compiler.malformed',
#  'error': True,
#  'message': 'Could not parse SoQL query "select * where trip_start_timestamp >= 2024-09-23T00:00:00 AND trip_start_timestamp <= 2024-09-23T23:59:59 limit 30000" at line 1 character 50: Expected one of end of input, `MINUS ALL\', `INTERSECT ALL\', `UNION ALL\', `MINUS\', `INTERSECT\', `UNION\', `|>\', `OFFSET\', `LIMIT\', `SEARCH\', `ORDER BY\', `HAVING\', or `GROUP BY\', but got `T00\'',
#  'data': {'query': 'select * where trip_start_timestamp >= 2024-09-23T00:00:00 AND trip_start_timestamp <= 2024-09-23T23:59:59 limit 30000',
#   'position': {}}}

# %%
# Calculate the date two months ago
current_datetime = datetime.now() - relativedelta(months=2)
formatted_date = current_datetime.strftime("%Y-%m-%d")

# Construct the query URL
url = (
    "https://data.cityofchicago.org/resource/ajtu-isnz.json?"
    f"$where=trip_start_timestamp >= '{formatted_date}T00:00:00'"
    f" AND trip_start_timestamp <= '{formatted_date}T23:59:59'"
    f"&$limit=30000"
)

# Make the GET request
response = requests.get(url)

data = response.json()

# data
# Out:
# [{'trip_id': 'e053060c21fd86db2c9f5ef38a25b759f6a8f088',
#   'taxi_id': '3b95cedc13d4a99243e1974616a6a25267c25878336faa586d4372370c847c3618753718dca887e3713efb476a5af11bc5f5a86c9785c9f749ca45f3f8be4764',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '180',
#   'trip_miles': '0',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '28',
#   'fare': '4.75',
#   'tips': '1',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '5.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': 'df08b741d0aadd2fdad465ec63d9364f7c4e439a',
#   'taxi_id': '42bfc19863617733aaa5ef96de670e3307690921a42d3df9e13ff7a35fa621088d7656cf297d3bb44306fa4ebc03bc631afc3c050b0562dea4b0b833e85818d2',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '947',
#   'trip_miles': '8.05',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '14',
#   'fare': '22',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '22',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.968069',
#   'dropoff_centroid_longitude': '-87.721559063',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7215590627, 41.968069]}},
#  {'trip_id': 'dd8188117ea30d18cc3233d1165e84761d101b7f',
#   'taxi_id': '0aba795cd29b34ff868043bc923a341f37c4f6d7afabe4976e8038a55e86e1c936bf00ca16d3e21dad4c499b89560f480a4ec9a763131c97e94f4e5bed56612a',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1560',
#   'trip_miles': '21.5',
#   'pickup_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'fare': '52',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '31',
#   'trip_total': '88',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': 'da0ddc6ad241a2a66df532dcdfe04cd0c402dd2b',
#   'taxi_id': '97c6416993b8151c499cefeb4d036a85605d391a116b3c657d1215fd8f93106709b2851350eb9b6a88cb995c432a1798982507eda6b3cf580366764ab860d357',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1560',
#   'trip_miles': '18.6',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '46.25',
#   'tips': '12.65',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '62.9',
#   'payment_type': 'Credit Card',
#   'company': 'Choice Taxi Association',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'd770c7a79b619708d14366de7f7efdb80376a7b2',
#   'taxi_id': 'f760c301740afe577d6c0e2f6de2cfecccf6ede158b8a3825331005da37a008716599169f4b467bc8b88e65318b5008499ad0ea4e05a7465c6bce4a1d5e70350',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1694',
#   'trip_miles': '7.95',
#   'pickup_community_area': '68',
#   'dropoff_community_area': '32',
#   'fare': '24',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '24',
#   'payment_type': 'Prcard',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.777196255',
#   'pickup_centroid_longitude': '-87.642497527',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6424975271, 41.7771962546]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': 'd3c7df2258a663b0cc377fddce3333c706856c1d',
#   'taxi_id': 'cd1574bcd03f25b70cb75eab0dbe94b0b04a60cfe2abb0b30805ba401e982c64a8b15a14ecc0abad88eb37c1f5e8023a1ae178b7484548cbdb72c05e270910a3',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '2166',
#   'trip_miles': '16.52',
#   'pickup_community_area': '76',
#   'fare': '41.25',
#   'tips': '7.01',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '53.76',
#   'payment_type': 'Credit Card',
#   'company': 'Top Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'd04d30bd0e1fd98889c1d94e02939a4a74ad3117',
#   'taxi_id': '624e8f2a6af3b7f032d3c40d6f925f6fc5f0bf6a358ecc7d01503a55553689cf6b36732e7d972a664d2d55e928baadb5d5d387884a6b0cf2701453f45c14a7cf',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1260',
#   'trip_miles': '15.8',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081500',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '39.5',
#   'tips': '8.8',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '52.3',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency, LLC',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.892507781',
#   'dropoff_centroid_longitude': '-87.626214906',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]}},
#  {'trip_id': 'cee65c62a98493f06fe6d66199eb4235e4d2e32f',
#   'taxi_id': '9e34e3008bafb42fc5fddcdc666ec08b3005f1100099c9cf7fbfc3e967b8fc6463d4dc51d87d41ca74f79504bf00e3f20cb95bc8fd7a4b53912f149e340fad98',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1500',
#   'trip_miles': '15.3',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '38.5',
#   'tips': '8.55',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '51.05',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'cd3923222cd2f9d78cc522a31d27f8edf17d8b8a',
#   'taxi_id': '897810ef0d64d2a9bd73c7c707459a14646e3e20478e13bc3985a7ae3b14076906876d1c234b6420eaeb82190818e53c7543ee3011ad3af41217d8d49f159672',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1860',
#   'trip_miles': '26.1',
#   'pickup_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'fare': '62.5',
#   'tips': '21.4',
#   'tolls': '0',
#   'extras': '44',
#   'trip_total': '127.9',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': 'cc04031bb9864bad907fa8c42dcd03a691f0287d',
#   'taxi_id': '1a248eb87ae578f15af2a14c2eb7b4b264f6babab9ad9cc93d655e1f83c3207e62beb1a4b088d75e8077a5421391d32171edacfcb3f6250657f8d3b9f0ebbaec',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '315',
#   'trip_miles': '0.69',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '5.5',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '8',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'c87a6bd3e60b33e0f1c7337b3f79cfa30d96e88f',
#   'taxi_id': '0642efa0706335c4f47ec1f5d0f84bbc4cedaeb693a0f4ccdb39c0e88bc7b266e7030d46b59e379fdac0257d144f252520e12897429ce8da7981b9752fbd6736',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:45:00.000',
#   'trip_seconds': '3738',
#   'trip_miles': '1',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '25',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'c609d32ebe121830ec7f26265288665c40185df8',
#   'taxi_id': 'a9263292f54a406cd0fb2bac808b9aaca91f770ad5e0fdb9f4ef446a77fe5b81144b2f88e1190ccf7045dc675362bd31b514fa0c5a5f5f6107bfd78693682805',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '678',
#   'trip_miles': '1.86',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '9',
#   'tips': '2.34',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.34',
#   'payment_type': 'Mobile',
#   'company': 'Tac - Yellow Cab Association',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'c3d2e6680a4d943e5db00f880cc5324d13f98030',
#   'taxi_id': '6bf28ce74fd9409f6e90444f26011a39fde5b4eeba19e2b77c9b9020905763db331c2a92fdcaad28ed0cdab55ada2a796a1f86a185110558adab12080685be08',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '666',
#   'trip_miles': '3.19',
#   'pickup_community_area': '3',
#   'dropoff_community_area': '72',
#   'fare': '11',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '1',
#   'trip_total': '12',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.96581197',
#   'pickup_centroid_longitude': '-87.655878786',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]},
#   'dropoff_centroid_latitude': '41.713148612',
#   'dropoff_centroid_longitude': '-87.675075312',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6750753124, 41.713148612]}},
#  {'trip_id': 'c2bb7cc1181af51b5befaf18df2dd289ad01a381',
#   'taxi_id': '83a03e93bf25ce653700ec8360c79b5f393ab5c9167f31f9151dd36c7f91538049c1e558bcda79475f8858037ab10446b5ad23997ffea791fe87fc56304eff34',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1620',
#   'trip_miles': '17',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '43',
#   'tips': '11.85',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '58.85',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': 'c0202854a4730b3d4daeea5aa3f973761e1a4d98',
#   'taxi_id': 'ee0a945778a6e3d37f8d6473b50fd38f0c7f24d05ead76110e6bccdeade9efcc5caa8198f63e86064e2bb53d78509d953288b07662ce961603c686eb7a25fed7',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1233',
#   'trip_miles': '11.47',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '44',
#   'fare': '30',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '30',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.740205756',
#   'dropoff_centroid_longitude': '-87.615969523',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6159695226, 41.7402057565]}},
#  {'trip_id': 'b48914ac0251bc75cd1f1b68fae5b612053ffae7',
#   'taxi_id': '1faf91220a6cf3f0796171853d220b94ea854732990c5674ae519cfa76806973dc8ff011cec176172e51e2622a8edb6c619ddc30fe5a4a0c1e6f58d46d948644',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '7',
#   'trip_miles': '0',
#   'fare': '30',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '30.5',
#   'payment_type': 'Credit Card',
#   'company': 'Chicago Independents'},
#  {'trip_id': 'b390cab26873818d53855f04ce751d1bf46421ee',
#   'taxi_id': 'e7a90b9dbb487806534dca4d79db0631b23e85ae3a734d93661ebc1c0e264c302b2a46e39e5ce96d4d2f118abbbc780353f596a5c385577ecf352ac8694a9faf',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1100',
#   'trip_miles': '11.07',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '14',
#   'fare': '28.75',
#   'tips': '4',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '37.25',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.968069',
#   'dropoff_centroid_longitude': '-87.721559063',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7215590627, 41.968069]}},
#  {'trip_id': 'b0f4609694cc898f5f99f1dcd54731cd9d752f74',
#   'taxi_id': '6c87f1d023a9d7146ae81b6aa4648bf98cec52cceb9f0854f80a246c81d94ffae05dd954ea58f3a3e82f2bc4793dc9cd826a6c3fdd5af3640dae2c2fe06e387e',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1440',
#   'trip_miles': '12.4',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '8',
#   'fare': '32.75',
#   'tips': '9.3',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '46.05',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'ac6a912d926f744bf635e994328ba38b3ea7d3d7',
#   'taxi_id': '51d13e9ec1a04be36d87a3746e0e4f8c68ca5ed59e6f7af9b137af2d622f0d6bb6a4d3534788bd879e6841ba52d9b8efd7d1771a6a416cd441d1640987b63ec3',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1316',
#   'trip_miles': '17.67',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.5',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '53',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': 'abf78df5576769c36b0c707fb6c88529099cb148',
#   'taxi_id': 'f5dba6c5cdc1520493ef3d4a8dc0e787aae7d08780d2457feebd2bec94839aecb5b88fad0ebc61c2accf01b5bbe1fa925fa8fdc4908eac20ea7dabeec2fb4a30',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:30:00.000',
#   'trip_seconds': '2554',
#   'trip_miles': '18.55',
#   'pickup_community_area': '76',
#   'fare': '46.5',
#   'tips': '7.95',
#   'tolls': '0',
#   'extras': '5.99',
#   'trip_total': '60.94',
#   'payment_type': 'Credit Card',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': 'a4a74c7d8e4b953cec5425c8850ec6af93c0d2df',
#   'taxi_id': '3618045f9110d4d88482266ade23659c1a50d32ac37f205c15614b1ada9d4ca14b171329afed5dfd81c7525bd5a05fe614cb63b2aa48d920626b519e20d9e146',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '240',
#   'trip_miles': '0.8',
#   'pickup_census_tract': '17031320100',
#   'dropoff_census_tract': '17031081402',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '5.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '5.25',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.884987192',
#   'pickup_centroid_longitude': '-87.620992913',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]},
#   'dropoff_centroid_latitude': '41.891971508',
#   'dropoff_centroid_longitude': '-87.612945414',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6129454143, 41.8919715078]}},
#  {'trip_id': 'a32ad7bc055ddde982306ffa70dba0e9bb8db8b8',
#   'taxi_id': '2f4e29a2c83f6b9c2b8ce735865fdddf49627f8d60bbfff69690a9839eb165a7615a2eed186208d8010288e533e6416eb5506d4619067b8754fd9664217c9eb0',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1070',
#   'trip_miles': '11.67',
#   'pickup_community_area': '22',
#   'dropoff_community_area': '2',
#   'fare': '29.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '29.75',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.92276062',
#   'pickup_centroid_longitude': '-87.699155343',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]},
#   'dropoff_centroid_latitude': '42.001571027',
#   'dropoff_centroid_longitude': '-87.695012589',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6950125892, 42.001571027]}},
#  {'trip_id': '9dacd03bd529eddca632c24d6c958ae3212a63dc',
#   'taxi_id': '89fc6b1f0628f328ccd1021fcf4e7318bb2f9962da9259b522bde63ca44f9f201a016291bbd2801fad04845cfd5b30b954afedccb22f6c49fadda05821804a06',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '7',
#   'trip_miles': '0',
#   'pickup_census_tract': '17031320100',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '32',
#   'fare': '16.5',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '22',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.884987192',
#   'pickup_centroid_longitude': '-87.620992913',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': '98b787bec689215b124b26e1bb2861d4a4dc6f7e',
#   'taxi_id': 'f20c9c5845dab1e51799b959d378c102763d4b31d738da7ea1f7fee763a4c830854cf6025fbe42e7c37dddab03ef2cf43bc775bdd6c5a4114d307dbf415728a5',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '988',
#   'trip_miles': '11.52',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '44',
#   'fare': '30.25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '30.25',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.740205756',
#   'dropoff_centroid_longitude': '-87.615969523',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6159695226, 41.7402057565]}},
#  {'trip_id': '94b7193211037a9bea65269de3c9a127537069de',
#   'taxi_id': '1aed6522859d97072638fadd1dba2c2fafbfd24956148205365e8e413a54aa8f26c521a0fc5e1d86bf0d464138806369569794a755c79cefdf20ee2771315ea3',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '823',
#   'trip_miles': '5.73',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '17',
#   'fare': '16.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '20.75',
#   'payment_type': 'Cash',
#   'company': 'Medallion Leasin',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.94651142',
#   'dropoff_centroid_longitude': '-87.806020002',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.8060200025, 41.9465114202]}},
#  {'trip_id': '914511d1dfb19cac9ec68110529173a2ec87d420',
#   'taxi_id': '667b6c6c56d5ae56fc1adbc8f7a40c8ed2820ba98ecef617b81044092e38f6e0f32ac1616659bafae6628e82195d5ca786d05262e53c935b1cfbdb5586f6d2f8',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1930',
#   'trip_miles': '19.17',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '48.5',
#   'tips': '10.8',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '64.8',
#   'payment_type': 'Mobile',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': '88b41d50fef10ac5c0e40dbceca2c2bb2122be46',
#   'taxi_id': '10a3a3db038a616cf1e784ef0c6bb9dd6e3d2cfb94f50e927e704d66ceb6313a1cc7b6bf620e40eeb4082ef0447c141bef6e0c8845682a91eae882021b75bc74',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1679',
#   'trip_miles': '10.08',
#   'pickup_community_area': '69',
#   'dropoff_community_area': '43',
#   'fare': '27.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '27.5',
#   'payment_type': 'Prcard',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.763246799',
#   'pickup_centroid_longitude': '-87.616134111',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6161341112, 41.7632467988]},
#   'dropoff_centroid_latitude': '41.761577908',
#   'dropoff_centroid_longitude': '-87.572781987',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5727819867, 41.7615779081]}},
#  {'trip_id': '866014d90397bd81e25648075848c224fe329b6b',
#   'taxi_id': 'bc38e7a06ef6fb44cebc048a2ee5b95e4895317666910e424e3fdc9c5c3e90c11830f684abd4bac75e22eab36698e564910a0edbd7289e4a397bffbe171ff8a6',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '540',
#   'trip_miles': '1.5',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '32',
#   'fare': '7.75',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '2',
#   'trip_total': '11.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.878865584',
#   'dropoff_centroid_longitude': '-87.625192142',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]}},
#  {'trip_id': '84c0ef700a92b1c3175286513e0de653574ae285',
#   'taxi_id': '05d337d606e1d74e7f5fe3dbaccdd1cf9a3163b8f21780397ab42c9f0036f3121555c7fcd36fa68f96436e47806756906832dc90bc703ddb0970c422451842bb',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1392',
#   'trip_miles': '19.89',
#   'pickup_community_area': '76',
#   'fare': '78',
#   'tips': '21.38',
#   'tolls': '0',
#   'extras': '7',
#   'trip_total': '106.88',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '79c80ef6ba144f0098999e87749317c294afb7c1',
#   'taxi_id': '1faf91220a6cf3f0796171853d220b94ea854732990c5674ae519cfa76806973dc8ff011cec176172e51e2622a8edb6c619ddc30fe5a4a0c1e6f58d46d948644',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '338',
#   'trip_miles': '2',
#   'pickup_community_area': '76',
#   'fare': '8',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '5.5',
#   'trip_total': '13.5',
#   'payment_type': 'Cash',
#   'company': 'Chicago Independents',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '78b58c71067761f6889b1d851eda32cbfbf26dd2',
#   'taxi_id': '515dbaaba624daeb95c3dfefb93bfc1764b99ed2ff96b71d422032764ae18c074537372c852fc523e497c5cc5227606e7edea21ed4f4b17ffb22f388c07e9863',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1440',
#   'trip_miles': '17.7',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.5',
#   'tips': '7',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '55.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '7456ac127dc16c1c8453ef6b31d5266bb296d18a',
#   'taxi_id': '6544c8051894de482dd3253d911c3e3d713b43beb93de2f63eece4cc682a8fb12516e8a4b05e3f0bb77602be3ed3686299d1b8b0c3ece2ab2d183119053ad5b8',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1332',
#   'trip_miles': '17.95',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.75',
#   'tips': '12.06',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '60.31',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '73ada633b85621722394ee56eae4e1ce846f9997',
#   'taxi_id': 'ffda53354c610fd3af1aee46d723028a49014e35f7280ca3d812716eb3cf1f0a763556368e4139b7183ee1fb36e26104de62bb86601f2fa16e3d96167e25b84e',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '596',
#   'trip_miles': '4.17',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '28',
#   'fare': '13',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '13',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': '6d6a67d294dc4e6d05948f1d7f20872d80dba715',
#   'taxi_id': 'ff60dabe17243a25435dcaf430a8b31615374bfc6be8416ff770306b39478cf34a5adedd497213f79bc39863f1048b62a3b7ceb4623d226104e44e82fae2438f',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1253',
#   'trip_miles': '17.24',
#   'pickup_community_area': '24',
#   'dropoff_community_area': '53',
#   'fare': '45.6',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '45.6',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.901206994',
#   'pickup_centroid_longitude': '-87.676355989',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6763559892, 41.9012069941]},
#   'dropoff_centroid_latitude': '41.673819904',
#   'dropoff_centroid_longitude': '-87.635739777',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6357397768, 41.6738199043]}},
#  {'trip_id': '6a3ac611c187223fd8d46602ef1fd5f8130a3430',
#   'taxi_id': '3b4da267511934cb42da9f200f346b4719f5d5d761e0a5f4df04bca3dab7b1eda6929cb7c0f134df62fbba37532fb856eae192d07cf0dfcb87f261977ad19ae6',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '560',
#   'trip_miles': '5.12',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '10',
#   'fare': '15',
#   'tips': '4.88',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '24.38',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.985015101',
#   'dropoff_centroid_longitude': '-87.804532006',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.8045320063, 41.9850151008]}},
#  {'trip_id': '674088b48549a0cf511f4b4339f5ef10945634a6',
#   'taxi_id': 'a39edfa6e2ec6209ece046221d25bdb4c4fee327de239ab3ba59ccf24f5c0fa3ae1d2eae70dca967a16209a8c676b71e685759e76214095b11b8896f4080e607',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '975',
#   'trip_miles': '8.45',
#   'pickup_community_area': '76',
#   'fare': '22.5',
#   'tips': '3',
#   'tolls': '0',
#   'extras': '6',
#   'trip_total': '32',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '5bb635ae8c8370bd283d13473652eae7df356907',
#   'taxi_id': '9a423881d4046f5590943c08ec5e58d59f5ebd91fe26aa9ef49ad0dfe587e3d3a78dc5e2d214e4d42120e5296ebadeb100494177de8b0fc8ef6a1b3e5290669b',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1320',
#   'trip_miles': '16.3',
#   'pickup_census_tract': '17031980000',
#   'pickup_community_area': '76',
#   'fare': '39.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '32',
#   'trip_total': '71.75',
#   'payment_type': 'Cash',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]}},
#  {'trip_id': '59d0508febd876016b3ab79f2dbc4e2b02496fb4',
#   'taxi_id': '5f1b2301b2ad74e61820da4a435a6281b1430fda6eadd2268dc4b1de8d4b75eb02930a8a1bc9905098ede61f7f6fadf734356334a27005f7752fdecaf66a89a8',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '11',
#   'trip_miles': '0',
#   'pickup_community_area': '43',
#   'dropoff_community_area': '43',
#   'fare': '65.87',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '65.87',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.761577908',
#   'pickup_centroid_longitude': '-87.572781987',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5727819867, 41.7615779081]},
#   'dropoff_centroid_latitude': '41.761577908',
#   'dropoff_centroid_longitude': '-87.572781987',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5727819867, 41.7615779081]}},
#  {'trip_id': '59bd7ff465f5458a580c68ce78de02de622515df',
#   'taxi_id': '799deebf2f513dbebcad07d26fedd03920ea747cb97055dadf972acd72f5b766b75041c294ea096a3ca6bc658dbd79f762c7079a94781c89f756a514f29c9c71',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '480',
#   'trip_miles': '1.6',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '8',
#   'tips': '4',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '12',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '4f035962a4365dfb1ced3ad6384a26d4d676c78b',
#   'taxi_id': 'ef7488a67b3bdf0eaa5355fbfba3dc68a90b9a1f84547f73f7ffa318cb4085eae706d5db6bff4363976e0d1c08e08729c5549e4132e9a797995456a0bf236ff2',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1337',
#   'trip_miles': '16.74',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '40.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '40.75',
#   'payment_type': 'Cash',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '4ae50516b756bec6d14ad22f5f4f4f82ef3d1a6e',
#   'taxi_id': '46c4778c3a32454511f96752c509c608955e293da45dbf245bf9eba5bef28916b7b61295d27aa8f61e4ad63b264051057ace630bce41b8aff5bc6853585fed15',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1440',
#   'trip_miles': '12.3',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '14',
#   'fare': '31.75',
#   'tips': '7.25',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '43',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.968069',
#   'dropoff_centroid_longitude': '-87.721559063',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7215590627, 41.968069]}},
#  {'trip_id': '3da4c5af41ec1e7712f546a959b393db31515749',
#   'taxi_id': '0097753fe60f11c95766e0c88d0b7fc93806043ea4713c6df7e093c643fc5f2d480e06d0e97f3e0b7c96bc399176f93b7ce98629b2433fd9f32f9c6483ae9855',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '0',
#   'trip_miles': '0',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '28',
#   'fare': '45',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '45',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.874005383',
#   'dropoff_centroid_longitude': '-87.66351755',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]}},
#  {'trip_id': '35344ed167d8654c7aa62d81925588c890429fa8',
#   'taxi_id': '5c34774d7f085ba650e743a8c07f3f9d5c78a19102b22fedfc6b1781c49e3300b6a7bb35a1f4fa87738713a590d8bd6cda2496bf224ca023935ab0e3759935b9',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1421',
#   'trip_miles': '11.87',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '3',
#   'fare': '31.25',
#   'tips': '7.15',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '42.9',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.96581197',
#   'dropoff_centroid_longitude': '-87.655878786',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6558787862, 41.96581197]}},
#  {'trip_id': '31f36880dd2b086c6c345cfe01af551286c7f6ee',
#   'taxi_id': 'a548c63608ec50e02a2311a0b6b1b2274995e3637ccb4ca7c3510c44756b5b0378906335f1e30563615c9ec8efd0f81ef97199ad869a68670f4d0eb85725ceaa',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '242',
#   'trip_miles': '0.75',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '9',
#   'tips': '2.3',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.3',
#   'payment_type': 'Mobile',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '241b859cc557dc164666ed298339b5246bf8c5bf',
#   'taxi_id': '2981edd199f55bdc8b5ed188de69e9f5d8116ae8d7a434fa0574d57740840e697755e4e77bb4ce8265289b6548d53674a5ac16dde44c3cf653e3ce1c8e064265',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '780',
#   'trip_miles': '11.9',
#   'pickup_community_area': '53',
#   'dropoff_community_area': '38',
#   'fare': '30',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '30',
#   'payment_type': 'Unknown',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.673819904',
#   'pickup_centroid_longitude': '-87.635739777',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6357397768, 41.6738199043]},
#   'dropoff_centroid_latitude': '41.812948939',
#   'dropoff_centroid_longitude': '-87.617859676',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6178596758, 41.8129489392]}},
#  {'trip_id': '21f2ce8340b41bbe4ce766d3f6ec0fc53f1ea4ed',
#   'taxi_id': '4a20ebb023f07066c94f8aa64453ff9991c21ed10791ed9d42c9fff7e45a08d19889082195ef3628673a8c118f26c30ba2c09d456a95bfe5c03dc2d13ffa4ae2',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '340',
#   'trip_miles': '1.63',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '9',
#   'tips': '2.3',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '11.3',
#   'payment_type': 'Mobile',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '1e9bc76a75eb46c9cfeeb9f688ab41bc19af29cf',
#   'taxi_id': '1a6d17595bc577385346e034ecbe0994d8f207d47d5b4c6f9fee70a1d4f37417db300370d59596dc2dd0bda2e35794bcdfd1bbead90d84a44aedd978ed269944',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1164',
#   'trip_miles': '12.54',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '70',
#   'fare': '31.5',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '31.5',
#   'payment_type': 'Prcard',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.745757713',
#   'dropoff_centroid_longitude': '-87.708365704',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7083657043, 41.7457577128]}},
#  {'trip_id': '1b39190185849b45495e3ee5ea6577aab5db750e',
#   'taxi_id': 'ea8e6df913a36562d8eddf662abe7722f4c0dc08527e9819364aed7a595eb61abb3728e49185db0616deb070840f410f6672275961076b6fcacc6bdfcf9edcf1',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-23T23:45:00.000',
#   'trip_seconds': '480',
#   'trip_miles': '1.6',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '8',
#   'fare': '8',
#   'tips': '2',
#   'tolls': '0',
#   'extras': '1.5',
#   'trip_total': '11.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '1a6b1444e28261a93508ecd1ef960967f987f02b',
#   'taxi_id': '9796a534d63f7be805edd46db7bd062bbdb30786df4dcdd622e95740c0661b6293778ab6774e1431fc23b40653d50294e7384ea6e8ad9160087a785251707127',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1269',
#   'trip_miles': '16.58',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '40.75',
#   'tips': '9.05',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '54.3',
#   'payment_type': 'Mobile',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '19e7a884727c6efd8ad1ffb3a638ebb2159b7647',
#   'taxi_id': '99c4682167a731b8fb229720c27d36b90990f69492b6b38c4bc1011c7f4cb0f94459490ec3f333b95d67cc0750a0c9b9f66077d8fafc208768a2570b05bcf8f4',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:15:00.000',
#   'trip_seconds': '1392',
#   'trip_miles': '17.12',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '42.5',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '52',
#   'payment_type': 'Credit Card',
#   'company': 'Globe Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.899602111',
#   'dropoff_centroid_longitude': '-87.633308037',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]}},
#  {'trip_id': '1695844f90c66068df56239184fd37b9ce5b017c',
#   'taxi_id': 'c7a8a53874bbcdb11e70a488485e8bdd0bb8cc0de8f5d98d3ef4d9c3223d7b4024a6d8fda9c00e8e55f3985e5a728ddce0175359c31e0bc5cd3c008d89b23ed1',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1274',
#   'trip_miles': '12.38',
#   'pickup_community_area': '69',
#   'dropoff_community_area': '7',
#   'fare': '31.5',
#   'tips': '4.8',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '36.3',
#   'payment_type': 'Prcard',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.763246799',
#   'pickup_centroid_longitude': '-87.616134111',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6161341112, 41.7632467988]},
#   'dropoff_centroid_latitude': '41.922686284',
#   'dropoff_centroid_longitude': '-87.649488729',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6494887289, 41.9226862843]}},
#  {'trip_id': '129f81d386bca3fa0a39543c116bba15590a24af',
#   'taxi_id': '9b0864961cf4141f2bbb24ce1046a6b791ce1e418045baa645ea08f6385111ca10f8a9fef54f830f5e1f64df9a4635f2fac6066c4a557ab15dc6cd1a2bd8bd59',
#   'trip_start_timestamp': '2024-09-23T23:45:00.000',
#   'trip_end_timestamp': '2024-09-24T00:00:00.000',
#   'trip_seconds': '1248',
#   'trip_miles': '13.69',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '24',
#   'fare': '34.25',
#   'tips': '7.75',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '46.5',
# ...
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.884987192',
#   'pickup_centroid_longitude': '-87.620992913',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]},
#   'dropoff_centroid_latitude': '41.89503345',
#   'dropoff_centroid_longitude': '-87.619710672',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6197106717, 41.8950334495]}},
#  {'trip_id': '3d343e4a75c7c5174a9d73a766aed16b596aa72d',
#   'taxi_id': 'cc704b98f0bedfa6a7ab9955eaa45a4e523b701960e047169e09b66c30790b0317df5125789c77736fcdb6925d44ab93d451e759082632cc8528542e52cd966c',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:00:00.000',
#   'trip_seconds': '803',
#   'trip_miles': '5.44',
#   'pickup_community_area': '76',
#   'fare': '16',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '20',
#   'payment_type': 'Cash',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '3c5f1fcba661a2d2905e14a65ebde1e670692d6c',
#   'taxi_id': '1a6d17595bc577385346e034ecbe0994d8f207d47d5b4c6f9fee70a1d4f37417db300370d59596dc2dd0bda2e35794bcdfd1bbead90d84a44aedd978ed269944',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:00:00.000',
#   'trip_seconds': '897',
#   'trip_miles': '9.49',
#   'pickup_community_area': '37',
#   'dropoff_community_area': '49',
#   'fare': '25',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '25',
#   'payment_type': 'Prcard',
#   'company': '5 Star Taxi',
#   'pickup_centroid_latitude': '41.80908443',
#   'pickup_centroid_longitude': '-87.632424524',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6324245245, 41.8090844303]},
#   'dropoff_centroid_latitude': '41.706587882',
#   'dropoff_centroid_longitude': '-87.623366512',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6233665115, 41.7065878819]}},
#  {'trip_id': '3bf6fc8218f4131fc5e803df0283afcd3ce0b929',
#   'taxi_id': '5445836ad254298c6af060d211ddf0e40b2f2a48146113096eeb1912a21a1ef7b6f3610cde49616bfdc9d502f3c6377fa78caa2b4548e6473a390d5d24056552',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:15:00.000',
#   'trip_seconds': '1260',
#   'trip_miles': '0',
#   'pickup_community_area': '56',
#   'dropoff_community_area': '22',
#   'fare': '33.75',
#   'tips': '10',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '47.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.79259236',
#   'pickup_centroid_longitude': '-87.769615453',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.7696154528, 41.7925923603]},
#   'dropoff_centroid_latitude': '41.92276062',
#   'dropoff_centroid_longitude': '-87.699155343',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6991553432, 41.9227606205]}},
#  {'trip_id': '3b03d94e04c6f87c47dda7d2b804610813b57aa5',
#   'taxi_id': '3d5fcccd2f2e4fb12eba0d94f8cdf657b20d405fece7c8a26571a7a0db7d8f8cf4f257a86ad49ad864417c6d8ceb0763b2207fbb57a78950f2566409e1b93fcd',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T21:45:00.000',
#   'trip_seconds': '360',
#   'trip_miles': '1',
#   'pickup_census_tract': '17031081403',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '32',
#   'fare': '6.25',
#   'tips': '1.75',
#   'tolls': '0',
#   'extras': '1.5',
#   'trip_total': '9.5',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.890922026',
#   'pickup_centroid_longitude': '-87.618868355',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6188683546, 41.8909220259]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': '3ab545fe2bbeb334f90c6a054452a1eed30b77fd',
#   'taxi_id': 'b3ee94a13b61037620cbbfc6a4a106d2ad628a06f0988f1eba5586d5387776d3781d71244392ff9c1afd5b69e65dfec45b2a936c2d101209044ff6365121ed6f',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:15:00.000',
#   'trip_seconds': '1920',
#   'trip_miles': '17.8',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081403',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '45',
#   'tips': '10.3',
#   'tolls': '0',
#   'extras': '6',
#   'trip_total': '61.3',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.890922026',
#   'dropoff_centroid_longitude': '-87.618868355',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6188683546, 41.8909220259]}},
#  {'trip_id': '391df3e25865e56c849b2c93610251e3fa62927d',
#   'taxi_id': 'a548c63608ec50e02a2311a0b6b1b2274995e3637ccb4ca7c3510c44756b5b0378906335f1e30563615c9ec8efd0f81ef97199ad869a68670f4d0eb85725ceaa',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:15:00.000',
#   'trip_seconds': '1493',
#   'trip_miles': '17.98',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '44.25',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '53.75',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': '384fcdf4553b8ea2b097ac62d37c668fa48f60de',
#   'taxi_id': 'ee0403d56ad861c2f3d4b1244497b07a47b61d3f9078de0f5c5f5c01ddcf997bd1f4d4d1e66f6a8c47f87048bf37321ab50e6d6b6e76423a09087487218e436b',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:00:00.000',
#   'trip_seconds': '1237',
#   'trip_miles': '7.16',
#   'fare': '76.84',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '76.84',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab'},
#  {'trip_id': '3687a0d2580becd8bf8a8999f92ce9eb53ed4044',
#   'taxi_id': '222a0a55fe5180e292a8e128804e081fa50b05a0329775f9344b50ee230f23d12635ee6a2429af764d01221057af04260089849cfb0192fa29bfda38362ffad6',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T21:45:00.000',
#   'trip_seconds': '342',
#   'trip_miles': '0.37',
#   'pickup_census_tract': '17031081700',
#   'dropoff_census_tract': '17031081500',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '8',
#   'fare': '0',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '0',
#   'payment_type': 'Cash',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.892042136',
#   'pickup_centroid_longitude': '-87.63186395',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6318639497, 41.8920421365]},
#   'dropoff_centroid_latitude': '41.892507781',
#   'dropoff_centroid_longitude': '-87.626214906',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]}},
#  {'trip_id': '3588d491eb19ccc58261fa565e9648b6d6dd5617',
#   'taxi_id': '9a26991eb0f188c6b8c8ad555d4fafbd9c3419259bfbd955a6268c59e1c1870e49037ecf205e53ea82dc3770c2f0286fa356df846369d7d3783a6dcfe726304d',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:15:00.000',
#   'trip_seconds': '1555',
#   'trip_miles': '17.26',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '43',
#   'tips': '9.5',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '57',
#   'payment_type': 'Mobile',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.884987192',
#   'dropoff_centroid_longitude': '-87.620992913',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6209929134, 41.8849871918]}},
#  {'trip_id': '3214310ffc3215f81ca7c85b792c0278758f5aa5',
#   'taxi_id': '95e2243f1be3ddd4b546741f6176fb12f2101fdc321377deb6a90915750c19d388915c3ee42dd04060b56e139f57dee79553cf85c71424715337145addae5fde',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:30:00.000',
#   'trip_seconds': '2100',
#   'trip_miles': '17.1',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081500',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.5',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '52.5',
#   'payment_type': 'Credit Card',
#   'company': '312 Medallion Management Corp',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.892507781',
#   'dropoff_centroid_longitude': '-87.626214906',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6262149064, 41.8925077809]}},
#  {'trip_id': '312897ca5b6ccb52799517689c2e955921edf428',
#   'taxi_id': 'ee0a945778a6e3d37f8d6473b50fd38f0c7f24d05ead76110e6bccdeade9efcc5caa8198f63e86064e2bb53d78509d953288b07662ce961603c686eb7a25fed7',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:00:00.000',
#   'trip_seconds': '995',
#   'trip_miles': '11.6',
#   'pickup_community_area': '39',
#   'dropoff_community_area': '68',
#   'fare': '29.75',
#   'tips': '0',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '29.75',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.808916283',
#   'pickup_centroid_longitude': '-87.596183344',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.5961833442, 41.8089162826]},
#   'dropoff_centroid_latitude': '41.777196255',
#   'dropoff_centroid_longitude': '-87.642497527',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6424975271, 41.7771962546]}},
#  {'trip_id': '30ce6bb5043d9ba28c42014a48640da1c3828821',
#   'taxi_id': 'e533bfdc483206f9c02c1c879a118d88f0a3ca1cd2703f3cf88e318716bbbb0c71d5f1c5f86b042b4ee1a06dbc750fa840acec0ebaf5fc1d90edbdc215114a1d',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:00:00.000',
#   'trip_seconds': '1145',
#   'trip_miles': '16.91',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031833000',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '28',
#   'fare': '41.25',
#   'tips': '6.86',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '52.61',
#   'payment_type': 'Credit Card',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.88528132',
#   'dropoff_centroid_longitude': '-87.6572332',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6572331997, 41.8852813201]}},
#  {'trip_id': '30cdc36951a7765d00b682a94bd764f917cab650',
#   'taxi_id': '515dbaaba624daeb95c3dfefb93bfc1764b99ed2ff96b71d422032764ae18c074537372c852fc523e497c5cc5227606e7edea21ed4f4b17ffb22f388c07e9863',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:15:00.000',
#   'trip_seconds': '1680',
#   'trip_miles': '13.4',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '5',
#   'fare': '34.75',
#   'tips': '5',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '43.75',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]},
#   'dropoff_centroid_latitude': '41.947791586',
#   'dropoff_centroid_longitude': '-87.683834942',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6838349425, 41.9477915865]}},
#  {'trip_id': '2f86161f2ff8fd31a78cab7072e18aa88b7b4e7e',
#   'taxi_id': '835869d6df51f9ec6e53cb4ac6a1f9e386c26f948cdcca5d86c515ba31b1c3e48e0b4d130c48ee65eb9011c2b185ede270ac586f9efd822c425286684ab5113b',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:00:00.000',
#   'trip_seconds': '1420',
#   'trip_miles': '17.81',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031839100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '43.5',
#   'tips': '7',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '55',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.880994471',
#   'dropoff_centroid_longitude': '-87.632746489',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]}},
#  {'trip_id': '2e2a14a7ee26d481e12312783c9027c95f6f0ccb',
#   'taxi_id': '91a036e3de3c1f459f2664801ea9388870751ae14e196e5be1caa84093318244f75aad0dbecdb8f5f6d2fb9ceec9c03c57acb5309769a88c68d06a49b157dae8',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:00:00.000',
#   'trip_seconds': '212',
#   'trip_miles': '0.97',
#   'pickup_census_tract': '17031839100',
#   'dropoff_census_tract': '17031081700',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '8',
#   'fare': '15',
#   'tips': '3.1',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '18.6',
#   'payment_type': 'Credit Card',
#   'company': 'City Service',
#   'pickup_centroid_latitude': '41.880994471',
#   'pickup_centroid_longitude': '-87.632746489',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6327464887, 41.8809944707]},
#   'dropoff_centroid_latitude': '41.892042136',
#   'dropoff_centroid_longitude': '-87.63186395',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6318639497, 41.8920421365]}},
#  {'trip_id': '283b3b45c9aa218574ee8463ecab31c3d4c20b3b',
#   'taxi_id': 'b649688173599f12325db808703dd3e14653807db2fdde48f5891daa24f8cef4c1a3711ec1881eda1920a36843bff16453782d5761c2d0a434ca1e4319b9f8d8',
#   'trip_start_timestamp': '2024-09-23T21:45:00.000',
#   'trip_end_timestamp': '2024-09-23T22:00:00.000',
#   'trip_seconds': '452',
#   'trip_miles': '4.23',
#   'pickup_community_area': '8',
#   'dropoff_community_area': '6',
#   'fare': '13',
#   'tips': '3.38',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '16.88',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.899602111',
#   'pickup_centroid_longitude': '-87.633308037',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6333080367, 41.899602111]},
#   'dropoff_centroid_latitude': '41.944226601',
#   'dropoff_centroid_longitude': '-87.655998182',
#   'dropoff_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6559981815, 41.9442266014]}},
#  ...]
